# %%
import pandas as pd

# %%
path = "/home/sokhorn/sokhorn/dataSet/groceries/Groceries_dataset.csv"
df = pd.read_csv(path)
df
# Out:
#        Unnamed: 0  Member_number        Date        itemDescription  Quantity
# 0               0           1808  21-07-2015         tropical fruit         1
# 1               1           2552  05-01-2015             whole milk         1
# 2               2           2300  19-09-2015              pip fruit         1
# 3               3           1187  12-12-2015       other vegetables         1
# 4               4           3037  01-02-2015             whole milk         1
# ...           ...            ...         ...                    ...       ...
# 38760       38760           4471  08-10-2014          sliced cheese         1
# 38761       38761           2022  23-02-2014                  candy         1
# 38762       38762           1097  16-04-2014               cake bar         1
# 38763       38763           1510  03-12-2014  fruit/vegetable juice         1
# 38764       38764           1521  26-12-2014               cat food         1
#
# [38765 rows x 5 columns]

# %%
item_sets_country = (
    df.groupby(
        ['Member_number', 'itemDescription', ])['Quantity']
    .sum().unstack().reset_index().fillna(0)
    .set_index("Member_number")
)

# %%
item_sets_country
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               0.0       0.0               0.0
# 1001                               0.0       0.0               0.0
# 1002                               0.0       0.0               0.0
# 1003                               0.0       0.0               0.0
# 1004                               0.0       0.0               0.0
# ...                                ...       ...               ...
# 4996                               0.0       0.0               0.0
# 4997                               0.0       0.0               0.0
# 4998                               0.0       0.0               0.0
# 4999                               0.0       0.0               0.0
# 5000                               0.0       0.0               0.0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
min_support_paper_dataset = "/home/sokhorn/sokhorn/dataSet/data/TrancReduuction/agaricus-lepiota-datasets.csv"

# %%
df =  pd.read_csv(min_support_paper_dataset)
# Out:
# 8123

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/sokhorn/sokhorn/Rupp/semester II/finalProject/apiori/newDataSet/grocery_dataset.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/sokhorn/sokhorn/Rupp/semester%20II/finalProject/apiori/newDataSet/grocery_dataset.ipynb#ch0000012?line=0'>1</a> df.columns.unique().sort()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:5021, in Index.sort(self, *args, **kwargs)
#    <a href='file:///home/sokhorn/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5015'>5016</a> @final
#    <a href='file:///home/sokhorn/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5016'>5017</a> def sort(self, *args, **kwargs):
#    <a href='file:///home/sokhorn/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5017'>5018</a>     """
# ...

# %%
min_support_paper_dataset
# Out:
# '/home/sokhorn/sokhorn/dataSet/data/TrancReduuction/agaricus-lepiota-datasets.csv'

# %%
import csv
data = set()
with open(min_support_paper_dataset) as f:
    readers = csv.reader(f, delimiter='\t',)
    for index, reader in enumerate(readers):
        print(reader)
        data.update(reader)
# Out:
# ['p,x,s,n,t,p,f,c,n,k,e,e,s,s,w,w,p,w,o,p,k,s,u']
# ['e,x,s,y,t,a,f,c,b,k,e,c,s,s,w,w,p,w,o,p,n,n,g']
# ['e,b,s,w,t,l,f,c,b,n,e,c,s,s,w,w,p,w,o,p,n,n,m']
# ['p,x,y,w,t,p,f,c,n,n,e,e,s,s,w,w,p,w,o,p,k,s,u']
# ['e,x,s,g,f,n,f,w,b,k,t,e,s,s,w,w,p,w,o,e,n,a,g']
# ['e,x,y,y,t,a,f,c,b,n,e,c,s,s,w,w,p,w,o,p,k,n,g']
# ['e,b,s,w,t,a,f,c,b,g,e,c,s,s,w,w,p,w,o,p,k,n,m']
# ['e,b,y,w,t,l,f,c,b,n,e,c,s,s,w,w,p,w,o,p,n,s,m']
# ['p,x,y,w,t,p,f,c,n,p,e,e,s,s,w,w,p,w,o,p,k,v,g']
# ['e,b,s,y,t,a,f,c,b,g,e,c,s,s,w,w,p,w,o,p,k,s,m']
# ['e,x,y,y,t,l,f,c,b,g,e,c,s,s,w,w,p,w,o,p,n,n,g']
# ['e,x,y,y,t,a,f,c,b,n,e,c,s,s,w,w,p,w,o,p,k,s,m']
# ['e,b,s,y,t,a,f,c,b,w,e,c,s,s,w,w,p,w,o,p,n,s,g']
# ['p,x,y,w,t,p,f,c,n,k,e,e,s,s,w,w,p,w,o,p,n,v,u']
# ['e,x,f,n,f,n,f,w,b,n,t,e,s,f,w,w,p,w,o,e,k,a,g']
# ['e,s,f,g,f,n,f,c,n,k,e,e,s,s,w,w,p,w,o,p,n,y,u']
# ['e,f,f,w,f,n,f,w,b,k,t,e,s,s,w,w,p,w,o,e,n,a,g']
# ['p,x,s,n,t,p,f,c,n,n,e,e,s,s,w,w,p,w,o,p,k,s,g']
# ['p,x,y,w,t,p,f,c,n,n,e,e,s,s,w,w,p,w,o,p,n,s,u']
# ...

# %%
set(data)
# Out:
# {'p,f,y,n,f,m,a,c,b,w,e,c,k,y,c,c,p,w,n,n,w,c,d',
#  'e,x,s,w,f,n,f,w,b,k,t,e,s,s,w,w,p,w,o,e,k,a,g',
#  'e,f,f,n,f,n,f,c,n,p,e,e,s,s,w,w,p,w,o,p,n,v,u',
#  'e,b,y,y,t,l,f,c,b,w,e,c,s,s,w,w,p,w,o,p,n,n,g',
#  'p,x,f,y,f,f,f,c,b,h,e,b,k,k,p,b,p,w,o,l,h,y,g',
#  'p,x,f,y,f,f,f,c,b,h,e,b,k,k,b,p,p,w,o,l,h,v,g',
#  'p,k,y,n,f,y,f,c,n,b,t,?,k,s,p,p,p,w,o,e,w,v,l',
#  'e,f,f,g,t,n,f,c,b,n,t,b,s,s,p,g,p,w,o,p,n,y,d',
#  'e,b,s,w,t,l,f,c,b,n,e,c,s,s,w,w,p,w,o,p,k,n,g',
#  'p,x,f,g,f,f,f,c,b,g,e,b,k,k,p,p,p,w,o,l,h,y,g',
#  'p,f,f,y,f,f,f,c,b,p,e,b,k,k,b,n,p,w,o,l,h,y,p',
#  'e,f,y,n,t,n,f,c,b,u,t,b,s,s,g,w,p,w,o,p,n,v,d',
#  'p,f,s,w,t,f,f,c,b,p,t,b,f,f,w,w,p,w,o,p,h,s,g',
#  'p,f,y,y,f,f,f,c,b,p,e,b,k,k,b,b,p,w,o,l,h,y,g',
#  'p,f,y,g,f,f,f,c,b,h,e,b,k,k,b,n,p,w,o,l,h,y,p',
#  'p,f,f,g,f,f,f,c,b,p,e,b,k,k,p,b,p,w,o,l,h,y,d',
#  'p,x,f,y,f,f,f,c,b,h,e,b,k,k,b,p,p,w,o,l,h,y,p',
#  'p,k,s,e,f,s,f,c,n,b,t,?,s,k,w,w,p,w,o,e,w,v,p',
#  'e,k,s,e,t,n,f,c,b,w,e,?,s,s,e,w,p,w,t,e,w,c,w',
# ...
